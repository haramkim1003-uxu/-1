# %% [markdown]
# <a href="https://colab.research.google.com/github/haramkim1003-uxu/-1/blob/main/250419_HTML%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0_%EB%B0%8F_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')

# %%
df
# Out:
# [                                       Olympic Games
#  0                                        Main topics
#  1  Bids Boycotts Ceremonies Charter Doping Host c...
#  2                                              Games
#  3                        Summer Winter Youth Esports
#  4                                     Regional games
#  5  African Asian Commonwealth European European m...
#  6                                      Defunct games
#  7                Ancient Esports Series Intercalated
#  8                                                vte,
#                                              Team Summer Olympic Games  \
#                                   Team (IOC code)                  No.
#  0                              Afghanistan (AFG)                   16
#  1                                  Albania (ALB)                   10
#  2                                  Algeria (ALG)                   15
# ...

# %%
len(df)
# Out:
# 55

# %%
df[0]
# Out:
#                                        Olympic Games
# 0                                        Main topics
# 1  Bids Boycotts Ceremonies Charter Doping Host c...
# 2                                              Games
# 3                        Summer Winter Youth Esports
# 4                                     Regional games
# 5  African Asian Commonwealth European European m...
# 6                                      Defunct games
# 7                Ancient Esports Series Intercalated
# 8                                                vte

# %%
df[6]
# Out:
#    No.               Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)  1105     879     781   2765
# 1    2      Russia (RUS)[I]   608     514     501   1623
# 2    3    Germany (GER)[II]   455     470     499   1424
# 3    4          China (CHN)   303     226     198    727
# 4    5  Great Britain (GBR)   298     339     343    980
# 5    6         France (FRA)   239     279     306    821
# 6    7          Italy (ITA)   229     201     221    651
# 7    8          Japan (JPN)   189     162     191    542
# 8    9        Hungary (HUN)   187     161     182    530
# 9   10      Australia (AUS)   182     192     226    600

# %%
df2 = df[6]

# %%
df2
# Out:
#    No.               Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)  1105     879     781   2765
# 1    2      Russia (RUS)[I]   608     514     501   1623
# 2    3    Germany (GER)[II]   455     470     499   1424
# 3    4          China (CHN)   303     226     198    727
# 4    5  Great Britain (GBR)   298     339     343    980
# 5    6         France (FRA)   239     279     306    821
# 6    7          Italy (ITA)   229     201     221    651
# 7    8          Japan (JPN)   189     162     191    542
# 8    9        Hungary (HUN)   187     161     182    530
# 9   10      Australia (AUS)   182     192     226    600

# %%
df2 = df2.drop('No.', axis=1)

# %%
df2
# Out:
#                 Nation  Gold  Silver  Bronze  Total
# 0  United States (USA)  1105     879     781   2765
# 1      Russia (RUS)[I]   608     514     501   1623
# 2    Germany (GER)[II]   455     470     499   1424
# 3          China (CHN)   303     226     198    727
# 4  Great Britain (GBR)   298     339     343    980
# 5         France (FRA)   239     279     306    821
# 6          Italy (ITA)   229     201     221    651
# 7          Japan (JPN)   189     162     191    542
# 8        Hungary (HUN)   187     161     182    530
# 9      Australia (AUS)   182     192     226    600

# %%
import matplotlib.pyplot as plt

# %%
df2.plot(kind = 'bar')
# Out:
# <Axes: >
