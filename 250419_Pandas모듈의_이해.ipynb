# %% [markdown]
# <a href="https://colab.research.google.com/github/haramkim1003-uxu/-1/blob/main/250419_Pandas%EB%AA%A8%EB%93%88%EC%9D%98_%EC%9D%B4%ED%95%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {'name': ['Pororo ','Krong','Pobi','Edie','Rupi'], 'Kor':[90,80,90,100,70],'math':[60,90,80,50,90],'science':[70,50,50,80,85],'art':[60,30,90,80,70],'social':[80,40,95,75,60],'English':[10,0,80,100,30]}

# %%
data
# Out:
# {'name': ['Pororo ', 'Krong', 'Pobi', 'Edie', 'Rupi'],
#  'Kor': [90, 80, 90, 100, 70],
#  'math': [60, 90, 80, 50, 90],
#  'science': [70, 50, 50, 80, 85],
#  'art': [60, 30, 90, 80, 70],
#  'social': [80, 40, 95, 75, 60],
#  'English': [10, 0, 80, 100, 30]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  Kor  math  science  art  social  English
# 0  Pororo    90    60       70   60      80       10
# 1    Krong   80    90       50   30      40        0
# 2     Pobi   90    80       50   90      95       80
# 3     Edie  100    50       80   80      75      100
# 4     Rupi   70    90       85   70      60       30

# %%
df.head()
# Out:
#       name  Kor  math  science  art  social  English
# 0  Pororo    90    60       70   60      80       10
# 1    Krong   80    90       50   30      40        0
# 2     Pobi   90    80       50   90      95       80
# 3     Edie  100    50       80   80      75      100
# 4     Rupi   70    90       85   70      60       30

# %%
df.head(2)
# Out:
#       name  Kor  math  science  art  social  English
# 0  Pororo    90    60       70   60      80       10
# 1    Krong   80    90       50   30      40        0

# %%
df.tail()
# Out:
#       name  Kor  math  science  art  social  English
# 0  Pororo    90    60       70   60      80       10
# 1    Krong   80    90       50   30      40        0
# 2     Pobi   90    80       50   90      95       80
# 3     Edie  100    50       80   80      75      100
# 4     Rupi   70    90       85   70      60       30

# %%
df.tail(2)
# Out:
#    name  Kor  math  science  art  social  English
# 3  Edie  100    50       80   80      75      100
# 4  Rupi   70    90       85   70      60       30
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Kor'].plot(kind='hist', bins=20, title='Kor')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['math'].plot(kind='hist', bins=20, title='math')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['science'].plot(kind='hist', bins=20, title='science')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['art'].plot(kind='hist', bins=20, title='art')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# ...

# %%
df.columns
# Out:
# Index(['name', 'Kor', 'math', 'science', 'art', 'social', 'English'], dtype='object')

# %%
df2 = pd.DataFrame(data, columns=['math', 'Kor', 'science','art','social','English'], index=['one', 'two', 'three', 'four', 'five'])

# %%
df2
# Out:
#        math  Kor  science  art  social  English
# one      60   90       70   60      80       10
# two      90   80       50   30      40        0
# three    80   90       50   90      95       80
# four     50  100       80   80      75      100
# five     90   70       85   70      60       30

# %%
#기술 통게분석:descriptive analaysis /개수, 평균, 중간값, 표준편차
df2.describe()
df2.describe()
# Out:
#             math         Kor    science        art     social     English
# count   5.000000    5.000000   5.000000   5.000000   5.000000    5.000000
# mean   74.000000   86.000000  67.000000  66.000000  70.000000   44.000000
# std    18.165902   11.401754  16.431677  23.021729  20.916501   43.931765
# min    50.000000   70.000000  50.000000  30.000000  40.000000    0.000000
# 25%    60.000000   80.000000  50.000000  60.000000  60.000000   10.000000
# 50%    80.000000   90.000000  70.000000  70.000000  75.000000   30.000000
# 75%    90.000000   90.000000  80.000000  80.000000  80.000000   80.000000
# max    90.000000  100.000000  85.000000  90.000000  95.000000  100.000000

# %%
df2.count()
# Out:
# math       5
# Kor        5
# science    5
# art        5
# social     5
# English    5
# dtype: int64

# %%
df2.mean()
# Out:
# math       74.0
# Kor        86.0
# science    67.0
# art        66.0
# social     70.0
# English    44.0
# dtype: float64

# %%
df3 = pd.DataFrame(data, columns=['kor', 'name', 'math', 'science', 'music'], index=['one', 'two', 'three', 'four', 'five'])

# %%
df3
# Out:
#        kor     name  math  science music
# one    NaN  Pororo     60       70   NaN
# two    NaN    Krong    90       50   NaN
# three  NaN     Pobi    80       50   NaN
# four   NaN     Edie    50       80   NaN
# five   NaN     Rupi    90       85   NaN

# %%
df3['music'] = 25

# %%
df3
# Out:
#        kor     name  math  science  music
# one    NaN  Pororo     60       70     25
# two    NaN    Krong    90       50     25
# three  NaN     Pobi    80       50     25
# four   NaN     Edie    50       80     25
# five   NaN     Rupi    90       85     25

# %%
df3['music'] = [20,10,30,50,25]

# %%
df3
# Out:
#        kor     name  math  science  music
# one    NaN  Pororo     60       70     20
# two    NaN    Krong    90       50     10
# three  NaN     Pobi    80       50     30
# four   NaN     Edie    50       80     50
# five   NaN     Rupi    90       85     25

# %%
df4 = df3.drop('music',axis = 1)

# %%
df4
# Out:
#        kor     name  math  science
# one    NaN  Pororo     60       70
# two    NaN    Krong    90       50
# three  NaN     Pobi    80       50
# four   NaN     Edie    50       80
# five   NaN     Rupi    90       85

# %%
df4.index.name = 'Order'

# %%
df4
# Out:
#        kor     name  math  science
# Order
# one    NaN  Pororo     60       70
# two    NaN    Krong    90       50
# three  NaN     Pobi    80       50
# four   NaN     Edie    50       80
# five   NaN     Rupi    90       85

# %%
df4.columns.name = 'subject'

# %%
df4
# Out:
# subject  kor     name  math  science
# Order
# one      NaN  Pororo     60       70
# two      NaN    Krong    90       50
# three    NaN     Pobi    80       50
# four     NaN     Edie    50       80
# five     NaN     Rupi    90       85

# %%
df5 = df4.loc['two':'four','name':'science']

# %%
df5
# Out:
# subject   name  math  science
# Order
# two      Krong    90       50
# three     Pobi    80       50
# four      Edie    50       80

# %%
df4
# Out:
# subject  kor     name  math  science
# Order
# one      NaN  Pororo     60       70
# two      NaN    Krong    90       50
# three    NaN     Pobi    80       50
# four     NaN     Edie    50       80
# five     NaN     Rupi    90       85

# %%
df6 = df4.iloc[1:4,1:4]

# %%
df6
# Out:
# subject   name  math  science
# Order
# two      Krong    90       50
# three     Pobi    80       50
# four      Edie    50       80

# %%
df7 = df4.loc[df4['name'] == 'Pororo',['name','math','science']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-9a80093eed52> in <cell line: 0>()
# ----> 1 df7 = df4.loc[df4['name'] == 'Pororo',['name','math','science']]
#
# NameError: name 'df4' is not defined

# %%
df7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-095ff158a76c> in <cell line: 0>()
# ----> 1 df7
#
# NameError: name 'df7' is not defined

# %%
import pandas as pd

# %%
timetable = {'period': ['1st period','2nd period','3rd period','4th period','5th period','6th period','7th period'], 'mon':[morality,math,science,technology,Korean,history,doesnot exist],'tue':[history,P.E,math,home,Chinese characters,English,Korean],'wen':[P.E,Korean,English,Chinese characters,history,morality,doesnot exist],'thu':[math,technology,Korean,history,P.E,Korean,home],'fri':[morality,history,English,math,Korean,science,doesnot exist]}
# Out:
#   File "<ipython-input-35-5681bd36e292>", line 1
#     timetable = {'period': ['1st period','2nd period','3rd period','4th period','5th period','6th period','7th period'], 'mon':[morality,math,science,technology,Korean,history,doesnot exist],'tue':[history,P.E,math,home,Chinese characters,English,Korean],'wen':[P.E,Korean,English,Chinese characters,history,morality,doesnot exist],'thu':[math,technology,Korean,history,P.E,Korean,home],'fri':[morality,history,English,math,Korean,science,doesnot exist]}
#                                                                                                                                                                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
timetable
# Out:
#        mon  tue  wen  thu  fri
# one    NaN  NaN  NaN  NaN  NaN
# two    NaN  NaN  NaN  NaN  NaN
# three  NaN  NaN  NaN  NaN  NaN
# four   NaN  NaN  NaN  NaN  NaN
# five   NaN  NaN  NaN  NaN  NaN
# six    NaN  NaN  NaN  NaN  NaN
# seven  NaN  NaN  NaN  NaN  NaN

# %%
timetable = timetable.loc['tue':'thu','2nd period':'5th period']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2nd period'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-dd141ebe622b> in <cell line: 0>()
# ----> 1 timetable = timetable.loc['tue':'thu','2nd period':'5th period']
#
# ...

# %%
timetable = pd.DataFrame(data, columns=['mon', 'tue', 'wen','thu','fri'], index=['one', 'two', 'three', 'four', 'five','six','seven'])

# %%
timetable
# Out:
#        mon  tue  wen  thu  fri
# one    NaN  NaN  NaN  NaN  NaN
# two    NaN  NaN  NaN  NaN  NaN
# three  NaN  NaN  NaN  NaN  NaN
# four   NaN  NaN  NaN  NaN  NaN
# five   NaN  NaN  NaN  NaN  NaN
# six    NaN  NaN  NaN  NaN  NaN
# seven  NaN  NaN  NaN  NaN  NaN

# %%
timetabie.index.time= 'time'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-a82c494f39b6> in <cell line: 0>()
# ----> 1 timetabie.index.time= 'time'
#
# NameError: name 'timetabie' is not defined

# %%
timetabie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d20d45f4afb4> in <cell line: 0>()
# ----> 1 timetabie
#
# NameError: name 'timetabie' is not defined

# %%
timetabie.columns.time = 'day'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-df031c498d15> in <cell line: 0>()
# ----> 1 timetabie.columns.time = 'day'
#
# NameError: name 'timetabie' is not defined

# %%
timetabie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-d20d45f4afb4> in <cell line: 0>()
# ----> 1 timetabie
#
# NameError: name 'timetabie' is not defined

# %%
timetable.index.Time

# %%
timetable =timetabie.loc['tue:2nd period':'thu:5th period','tue':'thu']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-5e831f04b9aa> in <cell line: 0>()
# ----> 1 timetable =timetabie.loc['tue:2nd period':'thu:5th period','tue':'thu']
#
# NameError: name 'timetabie' is not defined

# %%
timetabie.index.name = time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-151e527144c3> in <cell line: 0>()
# ----> 1 timetabie.index.name = time
#
# NameError: name 'time' is not defined

# %%
timetabie.columns.name = day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-a665a7f35832> in <cell line: 0>()
# ----> 1 timetabie.columns.name = day
#
# NameError: name 'day' is not defined

# %%
My favorite subject = timetable.drop('mon,fri',axis = 1)
# Out:
#   File "<ipython-input-57-70aa11058ac0>", line 1
#     My favorite subject = timetable.drop('mon,fri',axis = 1)
#        ^
# SyntaxError: invalid syntax
